# %% [markdown]
# Testing binary file
# ---

# %%
import binary_file_functions as bff
filename = "data.bin"

# %%
# creating a random binary file
bff.create_synthetic_data(filename, 1000)

# %%
data =bff.get_data(filename)

# %%
bff.get_file_size(data) # returns the size in bytes and bits of the file
# Out:
# (16000, 128000)

# %%
bff.check_size(data) # checks if the file size is a multiple of 16 (2 x 8 bytes packages)
# Out:
# True

# %%
bff.count_0xaa_entries(data) # counts the number of 0xaa entries in the file
# Out:
# 1000

# %%
bff.compute_crc(data) # computes the CRC of the file
# Out:
# 0

# %%
import os
os.remove(filename) # removes the file
