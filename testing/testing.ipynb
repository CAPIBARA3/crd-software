# %% [markdown]
# Testing binary file
# ---

# %%
import binary_file_tests as bft

# %%
bft.get_file_size() # returns the size in bytes and bits of the file
# Out:
# (1500, 12000)

# %%
bft.check_size() # checks if the file size is a multiple of 16 (2 x 8 bytes packages)
# Out:
# False

# %%
import binary_file_tests as bft
bft.count_0xaa_entries() # counts the number of 0xaa entries in the file
# Out:
# 7

# %%
bft.get_data()
# Out:
# b"\xaa\xfe\xe3t\x86M\x00\x08\x00\x00\x00\x00\x00\x00\x00\xaa\xfe\xe3t\x86\x1c\x02[\x00\x00\x00\x00\x00\x00\x00\xaa\xfe\xe3t\x86\x1a\x03\\\x00\x00\x00\x00\x00\x00\x00\xaa\xfe\xe3t\x86\xaf\x03\xe9\x00\x00\x00\x00\x00\x00\x00\xaa\xfe\xe3t\x86\x98\x02\xdf\x00\x00\x00\x00\x00\x00\x00\xaa\xfe\xe3t\x86\xb0\x02\xf7\x00\x00\x00\x00\x00\x00\x00\xaa\xfe\xe3t\x86V\x03\x10\x00\x00\x00\x00\x00\x00\x00\xaa\xfe\xe3t\x86\xe7\x02\xa0\x00\x00\x00\x00\x00\x00\x00\xaa\xfe\xe3t\x86\x84\x01\xc0\x00\x00\x00\x00\x00\x00\x00\xaa\xfe\xe3t\x86\xfc\x00\xb9\x00\x00\x00\x00\x00\x00\x00\xaa\xfe\xe3t\x86\x19\x02^\x00\x00\x00\x00\x00\x00\x00\xaa\xfe\xe3t\x86\xd6\x02\x91\x00\x00\x00\x00\x00\x00\x00\xaa\xfe\xe3t\x86\xa7\x01\xe3\x00\x00\x00\x00\x00\x00\x00\xaa\xfe\xe3t\x86;\x03}\x00\x00\x00\x00\x00\x00\x00\xaa\xfe\xe3t\x86\x96\x03\xd0\x00\x00\x00\x00\x00\x00\x00\xaa\xfe\xe3t\x86:\x00\x7f\x00\x00\x00\x00\x00\x00\x00\xaa\xfe\xe3t\x86%\x00`\x00\x00\x00\x00\x00\x00\x00\xaa\xfe\xe3t\x86C\x02\x04\x00\x00\x00\x00\x00\x00\x00\x
# ...

# %%
bft.compute_crc() # computes the CRC of the file
# Out:
# 0
